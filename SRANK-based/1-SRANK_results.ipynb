# %% [markdown]
# # Risultati dello script SRANK
# L'obiettivo è stabilire l'importanza di ciascuna feature per la procedura di feature selection.
#
# Il risultato è una score per ogni feature, più è alta, più è utile al clustering.

# %%
#librerie
from dataset_extended_class import dataframe_ext
from entropy_RANK_algorithm import SRANK
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns 
import pandas as pd
import numpy as np
#import del dataframe
df = pd.read_csv("../DatasetClientClustering.csv", 
                 engine='c', 
                 sep=',', 
                 encoding='latin-1')
df = df.drop(df.columns[list(np.arange(8))], axis=1)
df = df.drop(columns=["ClientID"])

current_investment = ["PortfolioRisk", "PortfolioHorizon", 
                      "AuM", "BondInvestments", "EquityInvestments",
                      "MoneyMarketInvestments", "OtherInvestments", "Cash"]

#TENTATIVO 1 - provo togliendo le variabili binarie
person_var = ["RiskPropension", "ClientInvestmentHorizon", 
              "ClientKnowledgeExperience", "ClientPotentialIndex",
              "IncomeHighLow", "Sex", "Age", "IncomeNeed", 
              "LongTermCareNeed", "ProtectionNeed",
              "InheritanceIndex", "PanicMood", "NoTrustInBanks"]
df_start = dataframe_ext(df[person_var]).standardize().clean()
df_start = df_start.df.drop(columns = df_start.binary_vars)

#impostazione di alcuni parametri per lo script
N_SAMPLE = 40
SAMPLE_SIZE = 50
max_score = (len(df_start.columns) - 1)*N_SAMPLE
###########################################
# SCRIPT RUN                              #
###########################################
scores = SRANK(df_start, N_SAMPLE = N_SAMPLE, SAMPLE_SIZE = SAMPLE_SIZE)
# Out:
# SAMPLE:  0
# 	 features:
# 		 RiskPropension
# 		 ClientInvestmentHorizon
# 		 ClientKnowledgeExperience
# 		 ClientPotentialIndex
# 		 Age
# 		 IncomeNeed
# 		 LongTermCareNeed
# 		 ProtectionNeed
# 		 InheritanceIndex
# SAMPLE:  1
# 	 features:
# 		 RiskPropension
# 		 ClientInvestmentHorizon
# 		 ClientKnowledgeExperience
# 		 ClientPotentialIndex
# 		 Age
# 		 IncomeNeed
# 		 LongTermCareNeed
# 		 ProtectionNeed
# 		 InheritanceIndex
# SAMPLE:  2
# 	 features:
# 		 RiskPropension
# 		 ClientInvestmentHorizon
# 		 ClientKnowledgeExperience
# 		 ClientPotentialIndex
# 		 Age
# 		 IncomeNeed
# 		 LongTermCareNeed
# 		 ProtectionNeed
# 		 InheritanceIndex
# SAMPLE:  3
# 	 features:
# 		 RiskPropension
# 		 ClientInvestmentHorizon
# 		 ClientKnowledgeExperience
# 		 ClientPotentialIndex
# 		 Age
# 		 IncomeNeed
# 		 LongTermCareNeed
# 		 ProtectionNeed
# 		 InheritanceIndex
# SAMPLE:  4
# 	 features:
# 		 RiskPropension
# 		 ClientInvestmentHorizon
# 		 ClientKnowledgeExperience
# 		 ClientPotentialIndex
# 		 Age
# 		 IncomeNeed
# 		 LongTermCareNeed
# 		 ProtectionNeed
# 		 InheritanceIndex
# SAMPLE:  5
# 	 features:
# 		 RiskPropension
# 		 ClientInvestmentHorizon
# 		 ClientKnowledgeExperience
# 		 ClientPotentialIndex
# 		 Age
# 		 IncomeNeed
# 		 LongTermCareNeed
# 		 ProtectionNeed
# 		 InheritanceIndex
# SAMPLE:  6
# 	 features:
# 		 RiskPropension
# 		 ClientInvestmentHorizon
# 		 ClientKnowledgeExperience
# 		 ClientPotentialIndex
# 		 Age
# 		 IncomeNeed
# 		 LongTermCareNeed
# 		 ProtectionNeed
# 		 InheritanceIndex
# SAMPLE:  7
# 	 features:
# 		 RiskPropension
# 		 ClientInvestmentHorizon
# 		 ClientKnowledgeExperience
# 		 ClientPotentialIndex
# 		 Age
# 		 IncomeNeed
# 		 LongTermCareNeed
# 		 ProtectionNeed
# 		 InheritanceIndex
# SAMPLE:  8
# 	 features:
# 		 RiskPropension
# 		 ClientInvestmentHorizon
# 		 ClientKnowledgeExperience
# 		 ClientPotentialIndex
# 		 Age
# 		 IncomeNeed
# 		 LongTermCareNeed
# 		 ProtectionNeed
# 		 InheritanceIndex
# SAMPLE:  9
# 	 features:
# 		 RiskPropension
# 		 ClientInvestmentHorizon
# 		 ClientKnowledgeExperience
# 		 ClientPotentialIndex
# 		 Age
# 		 IncomeNeed
# 		 LongTermCareNeed
# 		 ProtectionNeed
# 		 InheritanceIndex
# SAMPLE:  10
# 	 features:
# 		 RiskPropension
# 		 ClientInvestmentHorizon
# 		 ClientKnowledgeExperience
# 		 ClientPotentialIndex
# 		 Age
# 		 IncomeNeed
# 		 LongTermCareNeed
# 		 ProtectionNeed
# 		 InheritanceIndex
# SAMPLE:  11
# 	 features:
# 		 RiskPropension
# 		 ClientInvestmentHorizon
# 		 ClientKnowledgeExperience
# 		 ClientPotentialIndex
# 		 Age
# 		 IncomeNeed
# 		 LongTermCareNeed
# 		 ProtectionNeed
# 		 InheritanceIndex
# SAMPLE:  12
# 	 features:
# 		 RiskPropension
# 		 ClientInvestmentHorizon
# 		 ClientKnowledgeExperience
# 		 ClientPotentialIndex
# 		 Age
# 		 IncomeNeed
# 		 LongTermCareNeed
# 		 ProtectionNeed
# 		 InheritanceIndex
# SAMPLE:  13
# 	 features:
# 		 RiskPropension
# 		 ClientInvestmentHorizon
# 		 ClientKnowledgeExperience
# 		 ClientPotentialIndex
# 		 Age
# 		 IncomeNeed
# 		 LongTermCareNeed
# 		 ProtectionNeed
# 		 InheritanceIndex
# SAMPLE:  14
# 	 features:
# 		 RiskPropension
# 		 ClientInvestmentHorizon
# 		 ClientKnowledgeExperience
# 		 ClientPotentialIndex
# 		 Age
# 		 IncomeNeed
# 		 LongTermCareNeed
# 		 ProtectionNeed
# 		 InheritanceIndex
# SAMPLE:  15
# 	 features:
# 		 RiskPropension
# 		 ClientInvestmentHorizon
# 		 ClientKnowledgeExperience
# 		 ClientPotentialIndex
# 		 Age
# 		 IncomeNeed
# 		 LongTermCareNeed
# 		 ProtectionNeed
# 		 InheritanceIndex
# SAMPLE:  16
# 	 features:
# 		 RiskPropension
# 		 ClientInvestmentHorizon
# 		 ClientKnowledgeExperience
# 		 ClientPotentialIndex
# 		 Age
# 		 IncomeNeed
# 		 LongTermCareNeed
# 		 ProtectionNeed
# 		 InheritanceIndex
# SAMPLE:  17
# 	 features:
# 		 RiskPropension
# 		 ClientInvestmentHorizon
# 		 ClientKnowledgeExperience
# 		 ClientPotentialIndex
# 		 Age
# 		 IncomeNeed
# 		 LongTermCareNeed
# 		 ProtectionNeed
# 		 InheritanceIndex
# SAMPLE:  18
# 	 features:
# 		 RiskPropension
# 		 ClientInvestmentHorizon
# 		 ClientKnowledgeExperience
# 		 ClientPotentialIndex
# 		 Age
# 		 IncomeNeed
# 		 LongTermCareNeed
# 		 ProtectionNeed
# 		 InheritanceIndex
# SAMPLE:  19
# 	 features:
# 		 RiskPropension
# 		 ClientInvestmentHorizon
# 		 ClientKnowledgeExperience
# 		 ClientPotentialIndex
# 		 Age
# 		 IncomeNeed
# 		 LongTermCareNeed
# 		 ProtectionNeed
# 		 InheritanceIndex
# SAMPLE:  20
# 	 features:
# 		 RiskPropension
# 		 ClientInvestmentHorizon
# 		 ClientKnowledgeExperience
# 		 ClientPotentialIndex
# 		 Age
# 		 IncomeNeed
# 		 LongTermCareNeed
# 		 ProtectionNeed
# 		 InheritanceIndex
# SAMPLE:  21
# 	 features:
# 		 RiskPropension
# 		 ClientInvestmentHorizon
# 		 ClientKnowledgeExperience
# 		 ClientPotentialIndex
# 		 Age
# 		 IncomeNeed
# 		 LongTermCareNeed
# 		 ProtectionNeed
# 		 InheritanceIndex
# SAMPLE:  22
# 	 features:
# 		 RiskPropension
# 		 ClientInvestmentHorizon
# 		 ClientKnowledgeExperience
# 		 ClientPotentialIndex
# 		 Age
# 		 IncomeNeed
# 		 LongTermCareNeed
# 		 ProtectionNeed
# 		 InheritanceIndex
# SAMPLE:  23
# 	 features:
# 		 RiskPropension
# 		 ClientInvestmentHorizon
# 		 ClientKnowledgeExperience
# 		 ClientPotentialIndex
# 		 Age
# 		 IncomeNeed
# 		 LongTermCareNeed
# 		 ProtectionNeed
# 		 InheritanceIndex
# SAMPLE:  24
# 	 features:
# 		 RiskPropension
# 		 ClientInvestmentHorizon
# 		 ClientKnowledgeExperience
# 		 ClientPotentialIndex
# 		 Age
# 		 IncomeNeed
# 		 LongTermCareNeed
# 		 ProtectionNeed
# 		 InheritanceIndex
# SAMPLE:  25
# 	 features:
# 		 RiskPropension
# 		 ClientInvestmentHorizon
# 		 ClientKnowledgeExperience
# 		 ClientPotentialIndex
# 		 Age
# 		 IncomeNeed
# 		 LongTermCareNeed
# 		 ProtectionNeed
# 		 InheritanceIndex
# SAMPLE:  26
# 	 features:
# 		 RiskPropension
# 		 ClientInvestmentHorizon
# 		 ClientKnowledgeExperience
# 		 ClientPotentialIndex
# 		 Age
# 		 IncomeNeed
# 		 LongTermCareNeed
# 		 ProtectionNeed
# 		 InheritanceIndex
# SAMPLE:  27
# 	 features:
# 		 RiskPropension
# 		 ClientInvestmentHorizon
# 		 ClientKnowledgeExperience
# 		 ClientPotentialIndex
# 		 Age
# 		 IncomeNeed
# 		 LongTermCareNeed
# 		 ProtectionNeed
# 		 InheritanceIndex
# SAMPLE:  28
# 	 features:
# 		 RiskPropension
# 		 ClientInvestmentHorizon
# 		 ClientKnowledgeExperience
# 		 ClientPotentialIndex
# 		 Age
# 		 IncomeNeed
# 		 LongTermCareNeed
# 		 ProtectionNeed
# 		 InheritanceIndex
# SAMPLE:  29
# 	 features:
# 		 RiskPropension
# 		 ClientInvestmentHorizon
# 		 ClientKnowledgeExperience
# 		 ClientPotentialIndex
# 		 Age
# 		 IncomeNeed
# 		 LongTermCareNeed
# 		 ProtectionNeed
# 		 InheritanceIndex
# SAMPLE:  30
# 	 features:
# 		 RiskPropension
# 		 ClientInvestmentHorizon
# 		 ClientKnowledgeExperience
# 		 ClientPotentialIndex
# 		 Age
# 		 IncomeNeed
# 		 LongTermCareNeed
# 		 ProtectionNeed
# 		 InheritanceIndex
# SAMPLE:  31
# 	 features:
# 		 RiskPropension
# 		 ClientInvestmentHorizon
# 		 ClientKnowledgeExperience
# 		 ClientPotentialIndex
# 		 Age
# 		 IncomeNeed
# 		 LongTermCareNeed
# 		 ProtectionNeed
# 		 InheritanceIndex
# SAMPLE:  32
# 	 features:
# 		 RiskPropension
# 		 ClientInvestmentHorizon
# 		 ClientKnowledgeExperience
# 		 ClientPotentialIndex
# 		 Age
# 		 IncomeNeed
# 		 LongTermCareNeed
# 		 ProtectionNeed
# 		 InheritanceIndex
# SAMPLE:  33
# 	 features:
# 		 RiskPropension
# 		 ClientInvestmentHorizon
# 		 ClientKnowledgeExperience
# 		 ClientPotentialIndex
# 		 Age
# 		 IncomeNeed
# 		 LongTermCareNeed
# 		 ProtectionNeed
# 		 InheritanceIndex
# SAMPLE:  34
# 	 features:
# 		 RiskPropension
# 		 ClientInvestmentHorizon
# 		 ClientKnowledgeExperience
# 		 ClientPotentialIndex
# 		 Age
# 		 IncomeNeed
# 		 LongTermCareNeed
# 		 ProtectionNeed
# 		 InheritanceIndex
# SAMPLE:  35
# 	 features:
# 		 RiskPropension
# 		 ClientInvestmentHorizon
# 		 ClientKnowledgeExperience
# 		 ClientPotentialIndex
# 		 Age
# 		 IncomeNeed
# 		 LongTermCareNeed
# 		 ProtectionNeed
# 		 InheritanceIndex
# SAMPLE:  36
# 	 features:
# 		 RiskPropension
# 		 ClientInvestmentHorizon
# 		 ClientKnowledgeExperience
# 		 ClientPotentialIndex
# 		 Age
# 		 IncomeNeed
# 		 LongTermCareNeed
# 		 ProtectionNeed
# 		 InheritanceIndex
# SAMPLE:  37
# 	 features:
# 		 RiskPropension
# 		 ClientInvestmentHorizon
# 		 ClientKnowledgeExperience
# 		 ClientPotentialIndex
# 		 Age
# 		 IncomeNeed
# 		 LongTermCareNeed
# 		 ProtectionNeed
# 		 InheritanceIndex
# SAMPLE:  38
# 	 features:
# 		 RiskPropension
# 		 ClientInvestmentHorizon
# 		 ClientKnowledgeExperience
# 		 ClientPotentialIndex
# 		 Age
# 		 IncomeNeed
# 		 LongTermCareNeed
# 		 ProtectionNeed
# 		 InheritanceIndex
# SAMPLE:  39
# 	 features:
# 		 RiskPropension
# 		 ClientInvestmentHorizon
# 		 ClientKnowledgeExperience
# 		 ClientPotentialIndex
# 		 Age
# 		 IncomeNeed
# 		 LongTermCareNeed
# 		 ProtectionNeed
# 		 InheritanceIndex

# %%
###########################################
# PLOTTING                                #
###########################################
plt.figure(figsize = (16, 10))
mpl.style.use('fivethirtyeight')
sns.set(rc = {
                'axes.facecolor':'lightgray',
                'axes.edgecolor': 'lightgray',
                'figure.facecolor':'lightgray',
                'axes.labelcolor': '#414141',
                'text.color': '#414141',
                'xtick.color': '#414141',
                'ytick.color': '#414141',
                'grid.color': 'ghostwhite',
             })
chart = sns.barplot(x = "score_final",
                    y = "feature", 
                    data = scores.reset_index(), 
                    color = "royalblue", 
                    saturation = .7)

chart.set(xticks = [i for i in range(0, max_score+20, 20)])
chart.text(x = 0, y = -2, s="Final SRANK scores.", fontsize=25, fontweight='semibold', color='#414141')
chart.text(x = 0, y = -1, s="Higher score means higher importance", fontsize=18, fontweight='normal', color='#414141')
plt.xlabel("Final SRANK score\n (min = 0, max = {})".format(max_score), fontsize = 15, color='#414141')
plt.ylabel("Feature Name", fontsize = 15, color='#414141')
plt.draw()
plt.savefig('ranking_sampleSize100_nSample40.svg', format = "svg", dpi = 200, bbox_inches = 'tight')
plt.show()

###########################################
# SALVO LA TABELLA DEI RANKING            #
###########################################
scores.reset_index().to_csv(path_or_buf = "SRANKresults.csv", sep = ";", )
